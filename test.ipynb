# %%
import random
import pandas as pd
rows = ['Продолжительность эксплуатации;Количество ремонтов;Температура окр среды;Срок эксплуатации;Внезаплные отказы;Изделия с дефектами;Замена деталий;Смена обслуживания;Влажность окр среды;Страна производитель']
for i in range(50): 
  row = [str(i),
        str(random.randint(0,30)),
        str(random.randint(0,20)),
        str(random.randint(14,30)),
        str(random.randint(10,35)),
        str(random.randint(0,1)),
        str(random.randint(0,1)),
        str(random.randint(0,1)),
        str(random.randint(0,1)),
        str(random.randint(20,100)),
        str(random.randint(1,3))]
  rows.append(";".join(row))
s = "\n".join(rows)
#  s = s + str(i) + ';'
#  # Продолжительность эксплуатации
#  #Количество ремонтов
#  #Температура окр среды
#  #Срок эксплуатации
#  s = s + str (random.randint(0,1)) + ';'#наличие внезапных отказов
#  s = s + str (random.randint(0,1)) + ';'#Изделия с дефектами
#  s = s + str (random.randint(0,1)) + ';'#Замена деталей
#  s = s + str (random.randint(0,1)) + ';'#Смена обслуживающего персонала
#  s = s + str (random.randint(20,100)) + ';' #Влажность окр среды
#  s = s + str (random.randint(1,3))  #Страна производителя (1-Германия, 2-Япония, 3-Россия)
#  s = s + '\n';
    
f = open('dataset3.csv', 'w',encoding='utf8')
f.write(s)
f.close()

# %%
DATA = pd.read_csv("dataset3.csv", delimiter = ';')
DATA.head(51)
# Out:
#     Продолжительность эксплуатации  Количество ремонтов  \
# 0                                9                    0
# 1                               21                    2
# 2                               30                   20
# 3                                6                    0
# 4                                2                    5
# 5                               30                    7
# 6                               24                    9
# 7                                2                   19
# 8                               21                   19
# 9                                1                   19
# 10                               9                    0
# 11                              26                    2
# 12                              11                   11
# 13                              15                    7
# 14                               2                    3
# 15                               6                   17
# ...
